# %% [markdown]
# # PROGETTO PIPELINE DI MACHINE LEARNING PER LA REGRESSIONE SU DATASET DIABETES

# %%
import pandas as pd
import numpy as np

from sklearn.datasets import load_diabetes

# %%
diabetes = load_diabetes()

df = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)

df["target"] = diabetes.target

df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
df.info()

df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
#  10  target  442 non-null    float64
# dtypes: float64(11)
# memory usage: 38.1 KB
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.hist(figsize=(15, 10), bins=20)

plt.suptitle("Distribuzione delle feature", fontsize=16)

plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(15, 6))

sns.boxplot(data=df)

plt.title("Boxplot delle feature")

plt.xticks(rotation=45)

plt.show()

# %%
pd.plotting.scatter_matrix(
    df,
    figsize=(15,15),
    diagonal="hist"
)

plt.show()

# %%
X = df.drop("target", axis=1)

Y = df["target"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
print("Training set:", X_train.shape)
print("Test set:", X_test.shape)
# Out:
# Training set: (353, 10)
# Test set: (89, 10)

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR

# %%
models = {
    "Linear Regression":
    LinearRegression(),
    "Decision Tree":
    DecisionTreeRegressor(random_state=42),
    "Ridge": Ridge(),
    "Lasso": Lasso(),
    "KNN": KNeighborsRegressor(),
    "SVR": SVR()
}

# %%
from sklearn.model_selection import cross_val_score

# %%
results = {}

for name, model in models.items():

    scores = cross_val_score(
        model,
        X_train,
        y_train,
        cv=5,
        scoring="neg_mean_squared_error"
    )

    results[name] = scores.mean()

    print(f"{name}: {scores.mean():.2f}")
# Out:
# Linear Regression: -3143.02
# Decision Tree: -6450.14
# Ridge: -3639.40
# Lasso: -3997.78
# KNN: -3966.24
# SVR: -5321.08

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    "alpha": [0.001, 0.01, 0.1, 1, 10, 100]
}

# %%
ridge_grid = GridSearchCV(
    estimator=Ridge(),
    param_grid=param_grid,
    cv=5,
    scoring="neg_mean_squared_error"
)

ridge_grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.001, 0.01, 0.1, 1, 10, 100]},
#              scoring='neg_mean_squared_error')

# %%
print("Miglior valore di alpha:", ridge_grid.best_params_)
print("Miglior NMSE:", ridge_grid.best_score_)
# Out:
# Miglior valore di alpha: {'alpha': 0.1}
# Miglior NMSE: -3125.190774634348

# %%
best_model = ridge_grid.best_estimator_

best_model
# Out:
# Ridge(alpha=0.1)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
y_pred = best_model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"MSE: {mse:.2f}")
print(f"R²: {r2:.4f}")
# Out:
# MSE: 2856.49
# R²: 0.4609

# %%
from sklearn.model_selection import learning_curve
import numpy as np

# %%
train_sizes, train_scores, test_scores = learning_curve(
    best_model,
    X_train,
    y_train,
    cv=5,
    scoring="neg_mean_squared_error",
    train_sizes=np.linspace(0.1, 1.0, 10)
)

# %%
train_mean = -train_scores.mean(axis=1)
test_mean = -test_scores.mean(axis=1)

# %%
plt.figure(figsize=(8,6))

plt.plot(train_sizes, train_mean, label="Training Error")

plt.plot(train_sizes, test_mean, label="Validation Error")

plt.xlabel("Numero di campioni di Training")

plt.ylabel("Mean Squared Error")

plt.title("Learning Curve - Ridge Regression")

plt.legend()

plt.grid(True)

plt.show()

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# %%
pca_df = pd.DataFrame(X_pca,columns=["PC1", "PC2"])
pca_df["target"] = Y

# %%
plt.figure(figsize=(10,7))

scatter = plt.scatter(
    pca_df["PC1"],
    pca_df["PC2"],
    c=pca_df["target"],
    cmap="viridis"
)

plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("PCA del Dataset Diabetes")

plt.colorbar(scatter, label="Target")

plt.show()

# %%
from sklearn.linear_model import Ridge

ridge_pca = Ridge(alpha=0.1)

ridge_pca.fit(X_pca, Y)
# Out:
# Ridge(alpha=0.1)

# %%
y_pred_pca = ridge_pca.predict(X_pca)

# %%
plt.figure(figsize=(10, 7))

scatter = plt.scatter(
    X_pca[:,0],
    X_pca[:,1],
    c=y_pred_pca,
    cmap="viridis"
)

plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("Piano di regressione del modello Ridge nello spazio PCA")

plt.colorbar(scatter, label="Valore predetto")

plt.show()
